# %%
import pandas as pd

# %%
df=pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.size
# Out:
# 29764

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
data=df.dropna()

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2105 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2105 non-null   float64
#  2   FM        2105 non-null   float64
#  3   UC        2105 non-null   float64
#  4   DL        2105 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2105 non-null   float64
#  8   MSTV      2105 non-null   float64
#  9   ALTV      2105 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 246.7 KB

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2105, dtype: bool

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
Q1=df['LB'].quantile(0.25)
Q3=df['LB'].quantile(0.75)
IQR=Q3-Q1
print(Q1,Q3,IQR)
# Out:
# 126.0 140.0 14.0

# %%
lower_extreme=Q1-1.5*IQR

# %%
upper_extreme=Q3+1.5*IQR

# %%
print(lower_extreme,upper_extreme)
# Out:
# 105.0 161.0

# %%
data_LB_outliers=data[(data['LB']<lower_extreme) | (df['LB']>upper_extreme)]
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\2099541844.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_LB_outliers=data[(data['LB']<lower_extreme) | (df['LB']>upper_extreme)]

# %%
data_LB_outliers
# Out:
#               LB        AC        FM        UC        DL        DS        DP  \
# 134    52.000000  0.001590  0.000000  0.029851  0.000000  0.000000  0.000003
# 411   214.000000  0.000000  0.000000  0.001595  0.001595  0.000000  0.000000
# 610   214.000000  0.002469  0.002469  0.002469  0.000000  0.000004  0.000000
# 612   214.000000  0.005181  0.012953  0.002591  0.000000  0.000000  0.000000
# 785    52.000000  0.000834  0.013344  0.000000  0.000000  0.000000  0.000000
# 1027   51.842487  0.009485  0.000000  0.005420  0.002710  0.000005  0.000000
# 1103  214.000000  0.006972  0.000000  0.002960  0.000000  0.000000  0.000000
# 1406  214.000000  0.005068  0.000000  0.001689  0.000000  0.000000  0.000000
# 1504  214.000000  0.006189  0.000000  0.006189  0.000000  0.000000  0.000000
# 1834   52.188547  0.000000  0.001043  0.003128  0.007299  0.000000  0.000000
#
#            ASTV      MSTV  ALTV  MLTV      Width  Tendency     NSP
# ...

# %%
data.boxplot('LB')
# Out:
# <Axes: >

# %%
data_no_outliers=data[(data['LB']>=lower_extreme) & (df['LB']<=upper_extreme)]
data_no_outliers
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\2844955872.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_no_outliers=data[(data['LB']>=lower_extreme) & (df['LB']<=upper_extreme)]
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# ...

# %%
Q1=df['ASTV'].quantile(0.25)
Q3=df['ASTV'].quantile(0.75)
IQR=Q3-Q1
print(Q1,Q3,IQR)
# Out:
# 32.0 61.0 29.0

# %%
lower_extreme=Q1-1.5*IQR

# %%
upper_extreme=Q3+1.5*IQR

# %%
print(lower_extreme,upper_extreme)
# Out:
# -11.5 104.5

# %%
data_ASTV_outliers=data[(data['ASTV']<lower_extreme) | (df['ASTV']>upper_extreme)]
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\773768094.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_ASTV_outliers=data[(data['ASTV']<lower_extreme) | (df['ASTV']>upper_extreme)]

# %%
data_ASTV_outliers
# Out:
#               LB        AC        FM        UC        DL        DS   DP  \
# 131   158.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 232   123.000000  0.003650  0.005474  0.000000  0.000000  0.000000  0.0
# 345   139.000000 -0.000007  0.006593  0.000000  0.000000  0.000000  0.0
# 504   128.000000  0.008253  0.013755  0.004127  0.000000  0.000000  0.0
# 1014  139.000000  0.006312  0.000000  0.004509  0.000000  0.000000  0.0
# 1027   51.842487  0.009485  0.000000  0.005420  0.002710  0.000005  0.0
# 1195  138.000000  0.011752  0.000000  0.005342  0.000000  0.000000  0.0
# 1578  132.000000  0.000000 -0.002889  0.002994  0.000074  0.000000  0.0
# 1941  133.000000  0.000000  0.003562  0.006233  0.003562  0.000000  0.0
# 2008  125.000000  0.001196  0.001196  0.008373  0.009569  0.000000  0.0
#
#        ASTV  MSTV  ALTV       MLTV       Width  Tendency      NSP
# 131   -63.0   0.6  31.0   8.600000   92.000000       1.0  1.00000
# ...

# %%
data_no_outliers=data[(data['ASTV']>=lower_extreme) & (df['ASTV']<=upper_extreme)]
data_no_outliers
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\2942555720.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_no_outliers=data[(data['ASTV']>=lower_extreme) & (df['ASTV']<=upper_extreme)]
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# ...

# %%
Q1=df['ALTV'].quantile(0.25)
Q3=df['ALTV'].quantile(0.75)
IQR=Q3-Q1
print(Q1,Q3,IQR)
# Out:
# 0.0 11.0 11.0

# %%
lower_extreme=Q1-1.5*IQR

# %%
upper_extreme=Q3+1.5*IQR

# %%
print(lower_extreme,upper_extreme)
# Out:
# -16.5 27.5

# %%
data_ALTV_outliers=data[(data['ALTV']<lower_extreme) | (df['ALTV']>upper_extreme)]
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\807473087.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_ALTV_outliers=data[(data['ALTV']<lower_extreme) | (df['ALTV']>upper_extreme)]

# %%
data_ALTV_outliers
# Out:
#          LB        AC        FM        UC        DL   DS   DP  ASTV      MSTV  \
# 0     120.0  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0  0.500000
# 24    128.0  0.000000  0.000000  0.003311  0.000091  0.0  0.0  86.0  0.305801
# 25    124.0  0.000000  0.000000  0.000000 -0.000035  0.0  0.0  86.0  0.300000
# 27    124.0  0.000000  0.000000  0.000000  0.000000  0.0  0.0  87.0  0.200000
# 53    150.0  0.000000  0.000834  0.000000  0.000834  0.0  0.0  61.0  0.500000
# ...     ...       ...       ...       ...       ...  ...  ...   ...       ...
# 2106  136.0  0.000000  0.001096  0.007675  0.000000  0.0  0.0  78.0  0.400000
# 2114  137.0  0.000000  0.000000  0.007009  0.000000  0.0  0.0  81.0  0.359472
# 2115  140.0  0.000021  0.000000  0.006424  0.000000  0.0  0.0  83.0  0.200000
# 2116  140.0  0.003968  0.000000  0.003968  0.000000  0.0  0.0  80.0  0.200000
# 2125  142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0  0.400000
#
# ...

# %%
data_no_outliers=data[(data['ALTV']>=lower_extreme) & (df['ALTV']<=upper_extreme)]
data_no_outliers
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\1487517508.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_no_outliers=data[(data['ALTV']>=lower_extreme) & (df['ALTV']<=upper_extreme)]
#               LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.000000  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.000000  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.000000  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.000000  16.0
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.0  0.002099  26.0
# ...          ...       ...       ...       ...       ...  ...       ...   ...
# 2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.000000  77.0
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.000000  79.0
# ...

# %%
Q1=df['MLTV'].quantile(0.25)
Q3=df['MLTV'].quantile(0.75)
IQR=Q3-Q1
print(Q1,Q3,IQR)
# Out:
# 4.6 10.9 6.300000000000001

# %%
lower_extreme=Q1-1.5*IQR

# %%
upper_extreme=Q3+1.5*IQR

# %%
print(lower_extreme,upper_extreme)
# Out:
# -4.850000000000001 20.35

# %%
data_MLTV_outliers=data[(data['MLTV']<lower_extreme) | (df['MLTV']>upper_extreme)]
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\862548649.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_MLTV_outliers=data[(data['MLTV']<lower_extreme) | (df['MLTV']>upper_extreme)]

# %%
data_MLTV_outliers
# Out:
#          LB        AC        FM        UC        DL        DS        DP  ASTV  \
# 3     134.0  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000  16.0
# 10    151.0  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000  64.0
# 11    150.0  0.000000  0.000000  0.001014  0.000983  0.000000  0.000000  64.0
# 33    120.0  0.007506  0.102585  0.000800  0.000834 -0.000002  0.000000  28.0
# 35    120.0  0.006061  0.109091  0.007273  0.000000  0.000000  0.000000  27.0
# ...     ...       ...       ...       ...       ...       ...       ...   ...
# 1750  134.0  0.004800  0.001600  0.001600  0.003200  0.000000  0.003200  62.0
# 1800  143.0  0.000000  0.000000  0.003717  0.000000 -0.000004  0.000000  66.0
# 1818  139.0  0.011139  0.001007  0.007049  0.000000  0.000003  0.000000  53.0
# 1882  139.0  0.001835  0.000000  0.006422  0.000000  0.000000  0.000000  58.0
# 2033  129.0  0.000000  0.001122  0.006734  0.005767  0.000004  0.002245  67.0
#
# ...

# %%
data_no_outliers=data[(data['MLTV']>=lower_extreme) & (df['MLTV']<=upper_extreme)]
data_no_outliers
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\2558314383.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_no_outliers=data[(data['MLTV']>=lower_extreme) & (df['MLTV']<=upper_extreme)]
#               LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.000000  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.000000  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.000000  16.0
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.0  0.002099  26.0
# ...          ...       ...       ...       ...       ...  ...       ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.000000  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.000000  78.0
# ...

# %%
Q1=df['Width'].quantile(0.25)
Q3=df['Width'].quantile(0.75)
IQR=Q3-Q1
print(Q1,Q3,IQR)
# Out:
# 37.0 100.0 63.0

# %%
lower_extreme=Q1-1.5*IQR

# %%
upper_extreme=Q3+1.5*IQR

# %%
print(lower_extreme,upper_extreme)
# Out:
# -57.5 194.5

# %%
data_Width_outliers=data[(data['Width']<lower_extreme) | (df['Width']>upper_extreme)]
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\2143040935.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_Width_outliers=data[(data['Width']<lower_extreme) | (df['Width']>upper_extreme)]

# %%
data_Width_outliers
# Out:
#               LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 54    147.816574  0.000000  0.002502  0.000000 -0.000059  0.0  0.000000  70.0
# 64    141.000000  0.001282  0.000000  0.005128  0.000000  0.0  0.000000  25.0
# 120   123.000000  0.000000  0.000000  0.005004  0.004170  0.0  0.000000  47.0
# 389   129.000000  0.008264  0.053719  0.002066  0.000000  0.0  0.000000  37.0
# 704   130.030418  0.000000  0.352941  0.000000  0.000000  0.0  0.005348  80.0
# 829   152.000000  0.000000  0.000000  0.003854  0.000963  0.0  0.000000  58.0
# 860   142.000000  0.001471  0.001542  0.004412  0.000000  0.0  0.000000  39.0
# 1096  123.000000  0.017341  0.000000  0.001927  0.000000  0.0  0.000000  24.0
# 1273  115.000000  0.007032  0.000000  0.005626  0.000000  0.0  0.000000  20.0
# 1320  128.000000  0.006519  0.007823  0.005215  0.005215  0.0  0.001304  19.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# 54     0.3  69.000000   5.1 -174.0       1.0  3.004535
# ...

# %%
data_no_outliers=data[(data['Width']>=lower_extreme) & (df['Width']<=upper_extreme)]
data_no_outliers
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11912\418493513.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_no_outliers=data[(data['Width']>=lower_extreme) & (df['Width']<=upper_extreme)]
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# ...

# %%
# 2) statistical summary

# %%
print(df.describe())
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
# 3) Data Visualization

# %%
num_col=[i for i in df.columns if df[i].dtype != 'O']
num_col
# Out:
# ['LB',
#  'AC',
#  'FM',
#  'UC',
#  'DL',
#  'DS',
#  'DP',
#  'ASTV',
#  'MSTV',
#  'ALTV',
#  'MLTV',
#  'Width',
#  'Tendency',
#  'NSP']

# %%
cat_col=[i for i in df.columns if df[i].dtype == 'O']
cat_col
# Out:
# []

# %%
import matplotlib.pyplot as plt

# %%
# Histogram for numerical variables
df.hist(figsize=(12, 8))
plt.suptitle('Histograms of Numerical Variables')
plt.tight_layout()
plt.show()

# %%
# boxplot for numerical variables

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df)
plt.title('Boxplots for Numerical Variables')
plt.xticks(rotation=90)
plt.show()

# %%
# correlation heatmap

# %%
corr_matrix=df.corr()

# %%
corr_matrix
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063830  0.018777 -0.166570 -0.126959 -0.005438
# AC       -0.063830  1.000000  0.009433  0.072012 -0.093507 -0.033623
# FM        0.018777  0.009433  1.000000 -0.053226  0.009718  0.029901
# UC       -0.166570  0.072012 -0.053226  1.000000  0.190128 -0.006937
# DL       -0.126959 -0.093507  0.009718  0.190128  1.000000  0.058625
# DS       -0.005438 -0.033623  0.029901 -0.006937  0.058625  1.000000
# DP       -0.047724 -0.084590  0.121284  0.070658  0.145425  0.004285
# ASTV      0.242625 -0.231103 -0.032691 -0.181161 -0.069361  0.008452
# MSTV     -0.170473  0.134168  0.017055  0.189406  0.410102  0.016163
# ALTV      0.210728 -0.271390 -0.011936 -0.227304 -0.186967 -0.004398
# MLTV     -0.003457 -0.106529 -0.006237 -0.049460 -0.165750  0.034349
# Width    -0.118425  0.238436  0.097213  0.107397  0.410031  0.040832
# Tendency  0.236864  0.032481 -0.018339 -0.066610 -0.023569 -0.015398
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# pairplot for relationship between variables

# %%
sns.pairplot(df)
plt.show()

# %%
# violin plots

# %%
plt.figure(figsize=(10,8))
sns.violinplot(data=df)
plt.title('Violin Plot')
plt.show()

# %%
#Pattern Recognition and Insights

# %%
# Correlation analysis
corr_matrix= df.corr()
corr_matrix
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063830  0.018777 -0.166570 -0.126959 -0.005438
# AC       -0.063830  1.000000  0.009433  0.072012 -0.093507 -0.033623
# FM        0.018777  0.009433  1.000000 -0.053226  0.009718  0.029901
# UC       -0.166570  0.072012 -0.053226  1.000000  0.190128 -0.006937
# DL       -0.126959 -0.093507  0.009718  0.190128  1.000000  0.058625
# DS       -0.005438 -0.033623  0.029901 -0.006937  0.058625  1.000000
# DP       -0.047724 -0.084590  0.121284  0.070658  0.145425  0.004285
# ASTV      0.242625 -0.231103 -0.032691 -0.181161 -0.069361  0.008452
# MSTV     -0.170473  0.134168  0.017055  0.189406  0.410102  0.016163
# ALTV      0.210728 -0.271390 -0.011936 -0.227304 -0.186967 -0.004398
# MLTV     -0.003457 -0.106529 -0.006237 -0.049460 -0.165750  0.034349
# Width    -0.118425  0.238436  0.097213  0.107397  0.410031  0.040832
# Tendency  0.236864  0.032481 -0.018339 -0.066610 -0.023569 -0.015398
# ...

# %%
high_corr =corr_matrix[corr_matrix > 0.5]
high_corr
# Out:
#            LB   AC   FM   UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  Width  \
# LB        1.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# AC        NaN  1.0  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# FM        NaN  NaN  1.0  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# UC        NaN  NaN  NaN  1.0  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DL        NaN  NaN  NaN  NaN  1.0  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DS        NaN  NaN  NaN  NaN  NaN  1.0  NaN   NaN   NaN   NaN   NaN    NaN
# DP        NaN  NaN  NaN  NaN  NaN  NaN  1.0   NaN   NaN   NaN   NaN    NaN
# ASTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.0   NaN   NaN   NaN    NaN
# MSTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   1.0   NaN   NaN    NaN
# ALTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   1.0   NaN    NaN
# MLTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   1.0    NaN
# ...
